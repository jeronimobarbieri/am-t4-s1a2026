# %% [markdown]
# <a href="https://colab.research.google.com/github/jeronimobarbieri/am-t4-s1a2026/blob/main/aula2403_amt4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução de Python

# %%
a=1
b=2
print("A soma é", a+b)
# Out:
# A soma é 3

# %% [markdown]
# ## Segunda Camada

# %%
c=4
d=5
print("A multiplicação é", c*d)
# Out:
# A multiplicação é 20

# %% [markdown]
# # Bibliotecas e Funções de Python

# %%
import math

def equacao2grau(a, b, c):
  delta = b**2 - 4*a*c

  if(delta < 0):
    return 'Número sem raiz', delta

  x1 = (-b + math.sqrt(delta)) / (2*a)
  x2 = (-b - math.sqrt(delta)) / (2*a)

  return x1, x2

# %% [markdown]
# ## Teste de Funções Matemática

# %%
eq = equacao2grau(1, -3, 2)
print(eq)
# Out:
# (2.0, 1.0)

# %%
import random

for i in range(5):
  a = random.randint(-5, 1)
  b = random.randint(-10, 10)
  c = random.randint(-10, 10)

eq += equacao2grau(a, b, c)

# %%
print(eq)
# Out:
# (2.0, 1.0, -1.2706906325745548, 1.7706906325745548)

# %%
import random

for i in range(5):
  a = random.randint(-5, 1)
  b = random.randint(-10, 10)
  c = random.randint(-10, 10)

eq += equacao2grau(a, b, c)

print(eq[0])
# Out:
# 2.0

# %%
for i in range(12):
  if( i % 2 == 0):
    if(eq[i] != 'Número sem raiz'):
      print('X1: [',eq[i],']')
  else:
    if(eq[i] != 'Número sem raiz'):
      print('X2: [',eq[i],']\n')
# Out:
# X1: [ 2.0 ]
# X2: [ 1.0 ]
#
# X1: [ -1.2706906325745548 ]
# X2: [ 1.7706906325745548 ]
#
# X1: [ 0.5425728922436619 ]
# X2: [ 2.457427107756338 ]
#
# X2: [ -15 ]
#
# X1: [ -0.5941099943750894 ]
# X2: [ 3.927443327708423 ]
#
# X1: [ 7.653311931459037 ]
# X2: [ -0.6533119314590374 ]
